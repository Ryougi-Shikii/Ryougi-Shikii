# %%
# !git clone https://github.com/neuphonic/neutts.git
# %cd neutts
# Out:
# fatal: destination path 'neutts' already exists and is not an empty directory.
# /content/neutts

# %%
# !choco install espeak-ng
# !pip install -r requirements.txt

# %%
# !python -m examples.basic_example \
  --input_text "My name is Andy. I'm 25 and I just moved to London. The underground is pretty confusing, but it gets me around in no time at all." \
  --ref_audio samples/jo.wav \
  --ref_text samples/jo.txt

# %%
from neutts import neutts
import soundfile as sf

tts = neutts(
   backbone_repo="neuphonic/neutts-nano", # or 'neutts-nano-q4-gguf' with llama-cpp-python installed
   backbone_device="cpu",
   codec_repo="neuphonic/neucodec",
   codec_device="cpu"
)
input_text = "My name is Andy. I'm 25 and I just moved to London. The underground is pretty confusing, but it gets me around in no time at all."

ref_text = "samples/jo.txt"
ref_audio_path = "samples/jo.wav"

ref_text = open(ref_text, "r").read().strip()
ref_codes = tts.encode_reference(ref_audio_path)

wav = tts.infer(input_text, ref_codes, ref_text)
sf.write("test.wav", wav, 24000)

# %%
# !pip install transformers torch
from transformers import HubertModel
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2870686265.py in <cell line: 0>()
#       1 get_ipython().system('pip install transformers torch')
# ----> 2 from transformers import HubertModel
#
# ImportError: cannot import name 'HubertModel' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !apt-get update && apt-get install espeak-ng
# !pip install -r requirements.txt

# %% [markdown]
# **Reasoning**:
# The previous output indicates that `espeak-ng` is already installed and all Python requirements from `requirements.txt` are satisfied. The next step is to verify that `HubertModel` can be imported successfully, which was the original error. I will re-execute the cell that attempted to import `HubertModel`.

# %% [markdown]
# **Reasoning**:
# The `ImportError` indicates that `HubertModel` is not directly available from the top-level `transformers` package in the installed version. I need to import it from its specific submodule within `transformers` to resolve this.

# %%
import sys
# !{sys.executable} -m pip uninstall -y torchvision
# !{sys.executable} -m pip install torchvision==0.17.0

# Re-attempt the import after reinstalling torchvision
from transformers.models.hubert.modeling_hubert import HubertModel
print("HubertModel imported successfully!")
